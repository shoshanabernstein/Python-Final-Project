# %% [markdown]
# # ML Midterm Exam
# ## Heart Disease Prediction - ML Pipeline
#
# **Time:** 2 hours | **Total:** 100 pts + 15 bonus | **Dataset:** Heart Disease UCI (303 rows, 14 features)
#
# ---

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

sns.set_style("whitegrid")
# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("heart.csv")
print(f"Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns")
df.head()

# %% [markdown]
# ### Column Descriptions
# | Column | Description |
# |--------|-------------|
# | age | Age in years |
# | sex | 1=male, 0=female |
# | cp | Chest pain type (0-3) |
# | trestbps | Resting blood pressure |
# | chol | Serum cholesterol |
# | fbs | Fasting blood sugar > 120 (1/0) |
# | restecg | Resting ECG (0-2) |
# | thalach | Max heart rate achieved |
# | exang | Exercise induced angina (1/0) |
# | oldpeak | ST depression |
# | slope | Peak exercise ST slope |
# | ca | Major vessels (0-3) |
# | thal | Thalassemia type |
# | target | 1=disease, 0=no disease |

# %% [markdown]
# ---
# ## Part 1: Data Exploration & Visualization (20 pts)
#
# 1. Display shape, dtypes, missing values
# 2. Descriptive statistics
# 3. Correlation heatmap
# 4. Target distribution plot
# 5. **Which features are most correlated with target? Drop any? Why?**

# %%
# 1. Shape, dtypes, missing values

# %%
# 2. Descriptive statistics

# %%
# 3. Correlation heatmap

# %%
# 4. Target distribution

# %% [markdown]
# **Q5: Which features are most correlated with target? Would you drop any? Why?**
#
# *Your answer:*

# %% [markdown]
# ---
# ## Part 2: Linear Regression (15 pts)
#
# 6. Linear Regression: predict `thalach` from `age`
# 7. Plot regression line over scatter
# 8. Report R2 score
# 9. **Overfitting or underfitting? Evidence? How to improve?**

# %%
# 6. Linear Regression

# %%
# 7. Plot regression line

# %%
# 8. R2 score

# %% [markdown]
# **Q9: Overfitting or underfitting? What evidence? How to improve?**
#
# *Your answer:*

# %% [markdown]
# ---
# ## Part 3: Classification (40 pts)
#
# 10. Split 80/20
# 11. Logistic Regression
# 12. Confusion matrix
# 13. Accuracy, Precision, Recall, F1
# 14. ROC curve + AUC
# 15. **Interpret confusion matrix: false negatives impact?**
# 16. **Precision vs recall for medical diagnosis?**

# %%
# 10. Train/test split

# %%
# 11. Logistic Regression

# %%
# 12. Confusion matrix

# %%
# 13. Classification report

# %%
# 14. ROC curve and AUC

# %% [markdown]
# **Q15: How many patients told healthy but have disease? Real-world impact?**
#
# *Your answer:*

# %% [markdown]
# **Q16: Optimize precision or recall for medical diagnosis? Justify.**
#
# *Your answer:*

# %% [markdown]
# ---
# ## Part 4: Analysis & Reflection (25 pts)

# %% [markdown]
# **Q17: Compare R2 vs AUC. Which task handled better? Why?**
#
# *Your answer:*

# %% [markdown]
# **Q18: Which feature would you add to improve the classifier? Why?**
#
# *Your answer:*

# %% [markdown]
# **Q19: Two things you would do differently with more time/data?**
#
# *Your answer:*

# %% [markdown]
# ---
# ## Bonus: Clustering (+15 pts)
#
# 20. Pick 3 features, standardize
# 21. Elbow curve (inertia vs k=1..8)
# 22. K-Means with chosen k
# 23. 2D scatter of clusters
# 24. **Do clusters match disease labels? What does this mean?**

# %%
# 20. Select features and standardize

# %%
# 21. Elbow curve

# %%
# 22. K-Means

# %%
# 23. Cluster visualization

# %% [markdown]
# **Q24: Do clusters align with disease labels? What does this tell you?**
#
# *Your answer:*

# %% [markdown]
# ---
# ## Grading
# | Section | Points | Time |
# |---------|--------|------|
# | Part 1: Exploration | 20 | 25 min |
# | Part 2: Regression | 15 | 20 min |
# | Part 3: Classification | 40 | 40 min |
# | Part 4: Reflection | 25 | 15 min |
# | **Total** | **100** | **~100 min** |
# | Bonus: Clustering | +15 | ~20 min |
